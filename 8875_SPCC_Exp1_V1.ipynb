# %% [markdown]
# <a href="https://colab.research.google.com/github/hackergod00001/SPCC/blob/master/8875_SPCC_Exp1_V1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #symbol table generation using python

# %% [markdown]
# List of Operters and sybmols segregated manually

# %%
regex = '[a-zA-z0-9]$'
Operator=['=','+','-','*','/','^','%']
Symbols=['(',')',',',';']

# %% [markdown]
# Final table generatore code is here

# %%
i=0
table=[]
while i != 6:
    
    print("Enter Your Choice:")
    i=int(input("1. create  2. Search  3. Enter  Symbol  4. Remove  5. View  6. Exit"))
    
    if i==1:
        j=input("Enter your expression:")
        t_list=list(j)

        for i in t_list:
            if i.isalpha():
                j="Symbol:"+str(i)+" | Address: "+str(id(i))+" | Type: Identifier"
                table.append(j)
            elif i.isnumeric():
                j="Symbol:"+str(i)+" | Address: "+str(id(i))+" | Type: Numeric/Operand"
                table.append(j)
            elif str(i) in Symbols:
                j="Symbol:"+str(i)+" | Address: "+str(id(i))+" | Type: Symbols"
                table.append(j)
            elif str(i) in Operator:
                j="Symbol:"+str(i)+" | Address: "+str(id(i))+" | Type: Operator"
                table.append(j)
            else:
                j="Symbol:"+str(i)+" | Address: "+str(id(i))+" | Type: Unknown"
                table.append(j)
    
    
    elif i==2:
        e=input("Search the Identifier/Operator:")
        flag=0

        for p in range(len(table)):
            if str(e)==(table[p][7]):
                flag=1
                break
            
        if flag==1:
            print("Element is present")
        else:
            print("Element not found!")  

    elif i==3:
        j=input("Enter the equation:")
        o=list(j)
        
        for i in o:
            if i.isalpha():
                j="Symbol:"+str(i)+" | Address: "+str(id(i))+" | Type: Identifier"
                table.append(j)
            elif i.isnumeric():
                j="Symbol:"+str(i)+" | Address: "+str(id(i))+" | Type: Numeric/Operand"
                table.append(j)
            elif str(i) in Symbols:
                j="Symbol:"+str(i)+" | Address: "+str(id(i))+" | Type: Symbols"
                table.append(j)
            elif str(i) in Operator:
                j="Symbol:"+str(i)+" | Address: "+str(id(i))+" | Type: Operator"
                table.append(j)
            else:
                j="Symbol:"+str(i)+" | Address: "+str(id(i))+" | Type: Unknown"
                table.append(j)
    elif i==4:
        e=input("Remove the Identifier/Operator/Numeric/Operand/Symbols/Unknown:")
        l=0
        for p in range(len(table)-1,0,-1):
            if str(e)==(table[p][7]):
                l=p
                table.remove(table[p])
                print("Element Discarded!")
    elif i==5:
        for i in table:
            print(i)
# Out:
# Enter Your Choice:
# 1. create  2. Search  3. Enter  Symbol  4. Remove  5. View  6. Exit1
# Enter your expression:D=A+B*C
# Enter Your Choice:
# 1. create  2. Search  3. Enter  Symbol  4. Remove  5. View  6. Exit1
# Enter your expression:5
# Enter Your Choice:
# 1. create  2. Search  3. Enter  Symbol  4. Remove  5. View  6. Exit5
# Symbol:D | Address: 139687588170736 | Type: Identifier
# Symbol:= | Address: 139687588288048 | Type: Operator
# Symbol:A | Address: 139687588038896 | Type: Identifier
# Symbol:+ | Address: 139687588287536 | Type: Operator
# Symbol:B | Address: 139687588170544 | Type: Identifier
# Symbol:* | Address: 139687588980336 | Type: Operator
# Symbol:C | Address: 139687588170480 | Type: Identifier
# Symbol:5 | Address: 139687587777328 | Type: Numeric/Operand
# Enter Your Choice:
# 1. create  2. Search  3. Enter  Symbol  4. Remove  5. View  6. Exit1
# Enter your expression:X=W/M-L
# Enter Your Choice:
# ...
